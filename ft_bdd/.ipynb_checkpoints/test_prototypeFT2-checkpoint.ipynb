# %%
from prototypeFT2 import*

# %%
ftree = FT()

# %%
te = ftree.createEvent("te")
a = ftree.createEvent('a')
b = ftree.createEvent('b')
ftree.printFT(te)

# %%
c = ftree.createEvent('c')
d = ftree.createEvent('d')
ftree.createTreeAnd(te,a,b)
ftree.printFT(te)

# %%
ftree.createTreeAnd(te,a,b)
ftree.createTreeOr(a,c,d)

# %%
ftree.createTreeOr(b,a,d)
ftree.printFT(te)

# %%
ftree.destoryTree(b) #ノードbの子ノードを切り離す
ftree.printFT(te)

# %%
e = ftree.createEvent('e')
ftree.createTreeAnd(c,te,e)
# Out:
# This combination makes tree limitless

# %%
ftree.printFT(te)

# %%
ftree.createTreeAnd(b,e,d)

# %%
ftree.printFT(te)

# %%
#repeatedeventの表現はprototypeFT3.py
