# %%
from FT import*

# %%
ftree = FT()
te = ftree.createEvent("te")
a = ftree.createEvent('a')
b = ftree.createEvent('b')
c = ftree.createEvent('c')
d = ftree.createEvent('d')
e = ftree.createEvent('e')
f = ftree.createEvent('f')
ftree.createTreeOr(te,a,b)
ftree.printFT(te)

# %%
ftree.convertFTtoBDD(te)

# %%
ftree.createTreeAnd(a,c,d)
ftree.printFT(te)

# %%
ftree.convertFTtoBDD(te)

# %%
ftree.createTreeAnd(b,e,f)
ftree.printFT(te)

# %%
ftree.convertFTtoBDD(te)

# %%
ftree.createTreeAnd(b,d,f)
ftree.printFT(te)

# %%
ftree.convertFTtoBDD(te)
